# %%
pip install scikit-learn-extra
# Out:
# Collecting scikit-learn-extra
#   Downloading scikit_learn_extra-0.3.0-cp311-cp311-win_amd64.whl (340 kB)
#      ---------------------------------------- 0.0/340.5 kB ? eta -:--:--
#      --- ------------------------------------ 30.7/340.5 kB ? eta -:--:--
#      --- ------------------------------------ 30.7/340.5 kB ? eta -:--:--
#      --- ------------------------------------ 30.7/340.5 kB ? eta -:--:--
#      ----------- ------------------------ 112.6/340.5 kB 595.3 kB/s eta 0:00:01
#      ---------------- ------------------- 153.6/340.5 kB 654.6 kB/s eta 0:00:01
#      -------------------------------------  337.9/340.5 kB 1.2 MB/s eta 0:00:01
#      -------------------------------------- 340.5/340.5 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.13.3 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn-extra) (1.25.0)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn-extra) (1.11.1)
# Requirement already satisfied: scikit-learn>=0.23.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn-extra) (1.3.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (3.1.0)
# Installing collected packages: scikit-learn-extra
# Successfully installed scikit-learn-extra-0.3.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn_extra.cluster import KMedoids
from sklearn import datasets
import matplotlib.pyplot as plt

# %%
iris = datasets.load_iris()
X = iris.data

# %%
model = KMedoids(n_clusters=3,random_state=42)

# %%
model.fit(X)
# Out:
# KMedoids(n_clusters=3, random_state=42)

# %%
labels = model.labels_
medoids = model.medoid_indices_

# %%
plt.scatter(X[:,0],X[:,1],s=50)
plt.scatter(X[medoids,0],X[medoids,1],s=200)
plt.title("Medoids clustering")
plt.xlabel("Feature1")
plt.ylabel("Feature2")
plt.show()
